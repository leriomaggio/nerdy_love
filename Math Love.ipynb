# %%
# %matplotlib inline

# %%
from lovely_math_functions import L, O, V, E
from love import truly
import matplotlib.pyplot as plt

# %%
truly(L, O, V, E)  # U

# %% [markdown]
# <h1 style="font-size: 80px;">from the bottom of my</h1>

# %%
from lovely_math_functions import heart
from love import my
my(heart())
